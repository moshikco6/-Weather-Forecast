# %%
import pandas as pd
import json 
import requests 
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error

# %%
df_weather=pd.read_csv('Merge weather.csv')

# %%
df_weather
# Out:
#       Unnamed: 0 location        date  Temp_Max  Temp_Min  Temp_Ave
# 0              0   Berlin  2013-05-15      31.5      11.0      21.5  \
# 1              1   Berlin  2013-05-16      33.0      15.0      24.5
# 2              2   Berlin  2013-05-17      33.0      19.0      26.5
# 3              3   Berlin  2013-05-18      28.0      14.0      20.0
# 4              4   Berlin  2013-05-19      31.0      12.5      22.0
# ...          ...      ...         ...       ...       ...       ...
# 3648        3648   Berlin  2023-05-11      29.0      14.0      22.0
# 3649        3649   Berlin  2023-05-12      27.0      14.0      22.0
# 3650        3650   Berlin  2023-05-13      29.0      15.0      21.5
# 3651        3651   Berlin  2023-05-14      29.5      12.5      21.0
# 3652        3652   Berlin  2023-05-15      27.0      12.0      19.0
#
#       Feels_Like  humidity  Snow  Rain  Wind_Speed Cloud_Conver   Sunrise
# 0             16        55   0.0   1.0        45.5        27.8%  05:38:10  \
# 1             20        53   0.0   0.5        38.0        57.1%  05:36:24
# 2             22        48   0.0   0.0        35.5        65.5%  05:35:10
# 3             15        82   0.0   7.0        38.5        78.7%  05:33:26
# 4             15        68   0.0   0.0        20.5        24.6%  05:32:13
# ...          ...       ...   ...   ...         ...          ...       ...
# 3648          16        60   0.0   2.5        28.0        56.5%  05:45:17
# 3649          17        47   0.0   0.5        40.0        21.6%  05:43:27
# 3650          16        47   0.0   0.0        38.0        19.8%  05:41:38
# 3651          15        57   0.0   0.0        20.0        44.4%  05:40:19
# 3652          13        69   0.0   0.0        36.0        46.0%  05:38:32
#
#         Sunset                                        Description
# 0     21:21:40                  Partly cloudy throughout the day.
# 1     21:23:27  Becoming cloudy in the afternoon with early mo...
# 2     21:24:43                  Partly cloudy throughout the day.
# 3     21:26:28  Partly cloudy throughout the day with rain in ...
# 4     21:27:43                         Clearing in the afternoon.
# ...        ...                                                ...
# 3648  21:14:40                  Becoming cloudy in the afternoon.
# 3649  21:16:29                  Becoming cloudy in the afternoon.
# 3650  21:17:47               Clear conditions throughout the day.
# 3651  21:19:35                  Partly cloudy throughout the day.
# 3652  21:20:52        Partly cloudy throughout the day with rain.
#
# [3653 rows x 15 columns]

# %%
df_weather.index=pd.to_datetime(df_weather.index)

# %%
df_weather[['Temp_Ave']].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_weather[['Wind_Speed']].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_weather[['Rain']].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_weather['predict']=df_weather.shift(-1)['Temp_Ave']

# %%
df_weather=df_weather.ffill()
x=Ridge(alpha=.1)

# %%
predict=df_weather.columns[~df_weather.columns.isin(['location','predict','Unnamed: 0','Sunrise','Sunset','Description','Cloud_Conver'])]
predict
# Out:
# Index(['Temp_Max', 'Temp_Min', 'Temp_Ave', 'Feels_Like', 'humidity', 'Snow',
#        'Rain', 'Wind_Speed'],
#       dtype='object')

# %%
def backtest(df_weather,model,predict,start=1825,step=90):
    all_predictions=[]
    for i in range(start,df_weather.shape[0],step):
        train=df_weather.iloc[:i,:]
        test=df_weather.iloc[i:(i+step),:]
        model.fit(train[predict],train["predict"])
        preds=model.predict(test[predict])
        preds=pd.Series(preds,index=test.index)
        combined=pd.concat([test["predict"],preds],axis=1)
        combined.columns=["actual","prediction"]
        combined["diff"]=(combined["prediction"]-combined["actual"]).abs()
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions=backtest(df_weather,x,predict)

# %%
predictions

# %%
predictions["diff"].mean()

# %%
import numpy as np
import tensorflow as tf

df_weather['date'] = pd.to_datetime(df_weather['date'])
filtered_df = df_weather[(df_weather['date'].dt.month == 5) & (df_weather['date'].dt.day == 15)]


filtered_df
# Out:
#       Unnamed: 0 location       date  Temp_Max  Temp_Min  Temp_Ave
# 0              0   Berlin 2013-05-15      31.5      11.0      21.5  \
# 365          365   Berlin 2014-05-15      23.5       8.0      16.0
# 730          730   Berlin 2015-05-15      24.0       6.5      15.0
# 1096        1096   Berlin 2016-05-15      20.5       6.5      13.0
# 1461        1461   Berlin 2017-05-15      28.0      14.0      21.0
# 1826        1826   Berlin 2018-05-15      32.5      15.0      22.0
# 2191        2191   Berlin 2019-05-15      21.5       5.5      13.5
# 2557        2557   Berlin 2020-05-15      22.5       2.0      14.0
# 2922        2922   Berlin 2021-05-15      25.0      10.0      18.0
# 3287        3287   Berlin 2022-05-15      30.5      13.0      22.5
# 3652        3652   Berlin 2023-05-15      27.0      12.0      19.0
#
#       Feels_Like  humidity  Snow  Rain  Wind_Speed Cloud_Conver   Sunrise
# 0             16        55   0.0   1.0        45.5        27.8%  05:38:10  \
# 365            9        76   0.0   0.0        30.5        66.1%  05:38:22
# 730           10        68   0.0   0.0        26.5        21.7%  05:38:34
# 1096           5        74   0.0   2.0        40.0        74.3%  05:37:28
# 1461          15        73   0.0   0.5        35.0        39.6%  05:38:09
# 1826          15        68   0.0   6.0        30.5        48.2%  05:38:21
# 2191           6        57   0.0   0.0        35.5        22.0%  05:38:32
# 2557           9        56   0.0   0.0        25.5         8.9%  05:37:27
# 2922          12        68   0.0   3.5        23.5        49.6%  05:38:09
# 3287          14        58   0.0   1.0        23.0         8.2%  05:38:20
# 3652          13        69   0.0   0.0        36.0        46.0%  05:38:32
#
#         Sunset                                        Description
# 0     21:21:40                  Partly cloudy throughout the day.
# 365   21:21:29  Partly cloudy throughout the day with rain in ...
# 730   21:20:47                  Partly cloudy throughout the day.
# 1096  21:22:23  Partly cloudy throughout the day with a chance...
# 1461  21:21:41  Partly cloudy throughout the day with rain in ...
# 1826  21:21:30        Partly cloudy throughout the day with rain.
# 2191  21:20:49        Partly cloudy throughout the day with rain.
# 2557  21:22:25               Clear conditions throughout the day.
# 2922  21:21:44        Partly cloudy throughout the day with rain.
# 3287  21:21:33               Clear conditions throughout the day.
# 3652  21:20:52        Partly cloudy throughout the day with rain.

# %%
dates = np.array(filtered_df["date"])
temperatures = np.array(filtered_df["Temp_Ave"])


model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# קיבוע הפרמטרים של המודל
model.compile(loss='mean_squared_error', optimizer='adam')

# הכנת הנתונים לטיפול במודל
x = np.array([i+2013 for i in range(10)])
y = temperatures

# אימון המודל
model.fit(x, y, epochs=1000, verbose=0)

# חיזוי הטמפרטורה עבור השנה הבאה
prediction = model.predict([2023])

print(f"The predicted temperature for August 1st, 2023")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 19
#      16 y = temperatures
#      18 # אימון המודל
# ---> 19 model.fit(x, y, epochs=1000, verbose=0)
#      21 # חיזוי הטמפרטורה עבור השנה הבאה
#      22 prediction = model.predict([2023])
#
# File ~/.python/current/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.python/current/lib/python3.10/site-packages/keras/engine/data_adapter.py:1852, in _check_data_cardinality(data)
#    1845     msg += "  {} sizes: {}\n".format(
#    1846         label,
#    1847         ", ".join(
#    1848             str(i.shape[0]) for i in tf.nest.flatten(single_data)
#    1849         ),
#    1850     )
#    1851 msg += "Make sure all arrays contain the same number of samples."
# -> 1852 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 10
#   y sizes: 11
# Make sure all arrays contain the same number of samples.
